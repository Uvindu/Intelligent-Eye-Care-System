# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
# %matplotlib inline

m=6
def high(img):
    img = cv.resize(img,(int(img.shape[1]*m),int(img.shape[0]*m)))
    dst = cv.fastNlMeansDenoising(img,None,200.0, 7, 21)
    #dst2 = cv.fastNlMeansDenoising(dst,None,20.0,7,21)
    
    #dst3 = cv.fastNlMeansDenoising(dst2,None,50,7,21)
    '''
    dst4 = cv.fastNlMeansDenoisingColored(dst3,None,10,10,7,21)
    dst5 = cv.fastNlMeansDenoisingColored(dst4,None,10,10,7,21)
    dst6 = cv.fastNlMeansDenoisingColored(dst5,None,10,10,7,21)
    dst7 = cv.fastNlMeansDenoisingColored(dst6,None,10,10,7,21)
    dst8 = cv.fastNlMeansDenoisingColored(dst7,None,10,10,7,21)
    dst9 = cv.fastNlMeansDenoisingColored(dst8,None,10,10,7,21)
    dst10 = cv.fastNlMeansDenoisingColored(dst9,None,10,10,7,21)'''

    return dst #RGB

def blob(im):
    params = cv.SimpleBlobDetector_Params()
    params.filterByArea = True
    params.minArea = 270  # The dot in 20pt font has area of about 30
    params.filterByColor = 1
    #params.blobColor = 255
    params.filterByCircularity = 0
    params.filterByConvexity = 0
    params.filterByInertia = 0
    detector = cv.SimpleBlobDetector_create(params)
    keypoints = detector.detect(im)
    im_with_keypoints=cv.cvtColor(im,cv.COLOR_GRAY2BGR)
    try:
        pt1=im.shape[1]//2-keypoints[0].pt[0]
        pt2=im.shape[1]//2-keypoints[0].pt[1]
        my=cv.KeyPoint(im.shape[1]//2,im.shape[0]//2,0.2)
    except IndexError:pass
    #(100,180)
    #cv2.putText(im, "point: (%d,%d) " %(pt1,pt2), (10,10), cv2.FONT_HERSHEY_DUPLEX, 0.5, (147, 58, 31), 1)
    #im_with_keypoints = cv.drawKeypoints(im, keypoints[0:1], np.array([]), (255,0,255), 0)
    try:
        a=cv.drawKeypoints(im, [my], np.array([]), (255,255,0), 0)
        b=cv.drawKeypoints(im, [keypoints[0]], np.array([]), (255,255,0), 0)
        dist=(keypoints[0].pt[0]-my.pt[0])**3
        im_with_keypoints = cv.drawKeypoints(im, [my,keypoints[0]], np.array([]), (255,255,0), 0)
    except UnboundLocalError:
        dist=0
        try:
            im_with_keypoints = cv.drawKeypoints(im, [keypoints[0]], np.array([]), (255,255,0), 0)
        except:return im_with_keypoints,dist
    except IndexError:
        dist=0
        try:
            im_with_keypoints = cv.drawKeypoints(im, [my], np.array([]), (255,255,0), 0)
        except:return im_with_keypoints,dist
    return im_with_keypoints,dist



def is_blinking(img):
    gray=cv.cvtColor(img,cv.COLOR_BGR2GRAY)
    mask=np.array(255*(gray>170),dtype='uint8')
    black=sum(sum(gray==255))
    print(black)
    total=gray.shape[0]*gray.shape[1]
    eye_ratio=float(black)/total
    return eye_ratio,mask

# %%
for i in range(10,300,1):
    path='E:/ML_IP/ML_projects/Eye_tracking/gaze/eye_frames_2/left/%d__thres_49.jpg'%i
    img=cv.imread(path)
    img=cv.cvtColor(img,cv.COLOR_BGR2GRAY)
    xxx,dist=blob(high(img))
    print('distance :',dist)
    rat,mask=is_blinking(xxx)
    #print(i)
    plt.figure(figsize=(5,5))
    #plt.imshow(mask,'gray')
    plt.show()
    plt.figure(figsize=(5,5))
    plt.imshow(xxx)
    plt.show()
# Out:
# distance : -114.70644441519016
# 1096
# distance : -48.880103662172004
# 4246
# distance : -10.63289691685878
# 2128
# distance : -16.495707342276408
# 5923
# distance : 18.49448963917871
# 7145
# distance : 3204.731488573485
# 7863
# distance : 20970.20387155737
# 6816
# distance : 13776.1856040149
# 6713
# distance : 706.4062128005211
# 7288
# distance : 206.65257943952042
# 5983
# distance : 73.10265405821099
# 7218
# distance : -254.6805349753053
# 5942
# distance : -1.7676391373697697
# 2370
# distance : -0.11325744412329186
# 2111
# distance : -714.4078165762975
# 4616
# distance : 36.1131094805955
# 2329
# distance : 4.549835509725707
# 6349
# distance : 86.2140243261681
# 4074
# distance : 1.7379925885696452
# 4280
# distance : 74.85029096610378
# 5901
# distance : 35.76290496808298
# 3751
# distance : -6.570416005497474
# 2419
# distance : -239.58447554570716
# 1656
# distance : -111.40949042613263
# 2018
# distance : -538.1512829209066
# 1516
# distance : 6.565358896270187
# ...

# %%
path='E:/ML_IP/ML_projects/Eye_tracking/gaze/eye_frames/left/105__thres_48.jpg'
img=cv.imread(path)
img=cv.cvtColor(img,cv.COLOR_BGR2GRAY)
#plt.imshow(img,cmap='gray')

m=10
#img = cv.resize(img,(int(img.shape[1]*m),int(img.shape[0]*m)))
#img = cv.fastNlMeansDenoising(img,None,200.0, 7, 21)

#kernel = np.array([[-2,-2,-2], [-2,18,-2], [-2,-2,-2]])
#kernel = np.array(([0, -1, 0],[-1, 5, -1],[0, -1, 0]), dtype="int")
#img = cv.filter2D(img, -1, kernel)
#img= cv.Canny(img,0,200)
plt.figure()
hist_full = cv.calcHist([img],[0],None,[256],[200,256])
plt.plot(hist_full)
plt.figure()
plt.imshow(255*img>200,cmap='gray')

# %%
for i in range(50,51,1):
    path='E:/ML_IP/ML_projects/Eye_tracking/gaze/eye_frames_2/left/%d__thres_49.jpg'%i
    img=cv.imread(path)
    img=cv.cvtColor(img,cv.COLOR_BGR2GRAY)
    plt.figure()
    plt.imshow(img,cmap='gray')
    plt.figure()
    plt.hist(img.ravel(),256,[240,256]); plt.show()
