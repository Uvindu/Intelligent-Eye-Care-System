# %%
import dlib
import cv2
import numpy as np

# %%
model_path = "E:/ML_IP/ML_projects/Eye_tracking/gaze/gaze_tracking/trained_models/shape_predictor_68_face_landmarks.dat"

# %%
face_detector = dlib.get_frontal_face_detector()
shape = dlib.shape_predictor(model_path)

# %%
dir_='E:/ML_IP/ML_projects/Eye_tracking/gaze/test.jpg'
frame=cv2.imread(dir_)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_RGB2BGR))

# %%
face=face_detector(frame)[0]
a,b,c,d=face.left(),face.bottom(),face.right(),face.top()
landmarks=shape(frame,face)
points=landmarks.parts()

# %%
len(points), points[0].x, points[0].y
# Out:
# (68, 560, 313)

# %%
import cv2
from gaze_tracking import GazeTracking
webcam = cv2.VideoCapture(0)
while True:
    _, frame = webcam.read()
    try:
        face=face_detector(frame)[0]
        a,b,c,d=face.left(),face.bottom(),face.right(),face.top()
        landmarks=shape(frame,face)
        points=landmarks.parts()
        
    except: pass
    
    cv2.rectangle(frame,(a,b),(c,d),color=[255,0,0])
    cv2.imshow("Demo", frame)

    if cv2.waitKey(1) == 27:
        break
