# %%
from google.colab import drive

drive.mount('/content/gdrive') # experiments

# !rm -rf /content/dataset
# !mkdir -p /content/dataset

# %%
# !cp -r '/content/gdrive/My Drive/full_hust_dataset' /content/dataset/

# %%
# %%capture
# %cd /content/dataset/full_hust_dataset/train/
# !zip -s- blink.zip -O combined_train_blink.zip
# !zip -s- unblink.zip -O combined_train_unblink.zip

# %cd /content/dataset/full_hust_dataset/test/
# !zip -s- blink.zip -O combined_test_blink.zip
# !zip -s- unblink.zip -O combined_test_unblink.zip

# %%
import shutil
shutil.copyfile('/content/dataset/full_hust_dataset/train/combined_train_blink.zip', '/content/gdrive/My Drive/hust_full_combined/combined_train_blink.zip')
shutil.copyfile('/content/dataset/full_hust_dataset/train/combined_train_unblink.zip', '/content/gdrive/My Drive/hust_full_combined/combined_train_unblink.zip')

shutil.copyfile('/content/dataset/full_hust_dataset/test/combined_test_blink.zip', '/content/gdrive/My Drive/hust_full_combined/combined_test_blink.zip')
shutil.copyfile('/content/dataset/full_hust_dataset/test/combined_test_unblink.zip', '/content/gdrive/My Drive/hust_full_combined/combined_test_unblink.zip')
