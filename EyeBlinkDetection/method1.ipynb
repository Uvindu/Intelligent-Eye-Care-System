# %%
from google.colab import drive

drive.mount('/content/gdrive') # experiments

# !rm -rf /content/dataset
# !mkdir -p /content/dataset
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Sync datasets from Drive

# %%
# !rm -rf /content/full_hust_dataset_combined
# !mkdir /content/full_hust_dataset_combined

import glob, shutil
for data_file in glob.glob(f'/content/gdrive/My Drive/full_hust_dataset_combined/*test*.zip'):

  file_name = data_file.split('/')[-1].replace('test', 'train')
  shutil.copyfile(data_file, f'/content/full_hust_dataset_combined/{file_name}')

# %%
for zip_file in glob.glob('/content/*/*train*.zip'):
  # !unzip $zip_file

# %% [markdown]
# ## Update modules

# %%
import shutil

def send_modules():
  # !rm -rf '/content/gdrive/My Drive/EyeTracking/modules'
  shutil.copytree('/content/modules', '/content/gdrive/My Drive/EyeTracking/modules')
  print(f'modules send to : /content/gdrive/My Drive/EyeTracking/modules')
def recieve_modules():
  # !rm -rf '/content/modules'
  shutil.copytree('/content/gdrive/My Drive/EyeTracking/modules', '/content/modules')
  print('modules recieved to : /content/modules')

# %%
#recieve_modules()
#send_modules()
# Out:
# modules send to : /content/gdrive/My Drive/EyeTracking/modules

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from modules.get_features import get_features_for_sample
from modules.data_utils import get_dataset_filedirvslabel
from modules.feature_functions import feature_func_eyeimages, feature_func_frp
from modules.detectors import get_detectors


blink_data_dir = '/content/blink'
unblink_data_dir= '/content/unblink'

# %% [markdown]
# ## Create dataset

# %%
def create_feature_dataset(blink_data_dir, unblink_data_dir, feature_func= feature_func_frp, n_frames_per_vid=10, type_= 'train', train_ratio=0.8):
  dataset =[]

  np.random.seed(10)
  dataset_filedirvslabel_all = sorted(list(get_dataset_filedirvslabel(blink_data_dir))+ list(get_dataset_filedirvslabel(unblink_data_dir)))
  np.random.shuffle(dataset_filedirvslabel_all)

  train_len= int(len(dataset_filedirvslabel_all)*train_ratio)
  
  if type_=='train':dataset_filedirvslabel= dataset_filedirvslabel_all[:train_len]
  else:dataset_filedirvslabel= dataset_filedirvslabel_all[train_len:]

  detector, landmark_detector = get_detectors()

  #for dataset_filedirvslabel_sample in dataset_filedirvslabel:
  #  sample_id = int(dataset_filedirvslabel_sample[0][0].split('/')[-3])
  
  for sample_id in range(len(dataset_filedirvslabel)):
    features, label = get_features_for_sample(dataset_filedirvslabel, sample_id, feature_func, detector, landmark_detector)
    try:
      features.shape #to check features is not None

      if len(features[0])==n_frames_per_vid:dataset.append(features,label)
      else:print('length features are not 10 !!!')

    except:print(f'features not extracted : {sample_id}')
  return dataset

# %% [markdown]
# ## Train

# %%
import torch
from torch import nn
from modules.nn_models import simple_lstm
from modules.train import train
from modules.data import get_dataset

device= 'cuda' if torch.cuda.is_available() else 'cpu'
model = simple_lstm(lstm_input_feature_size= 1, bidirectional=False).to(device)
criterion= nn.BCELoss().to(device)
opt= torch.optim.Adam(model.parameters(), lr= 0.001)

dataset_train = create_feature_dataset(blink_data_dir, unblink_data_dir, feature_func= feature_func_frp, n_frames_per_vid=10, type_= 'train')
dataset_test = create_feature_dataset(blink_data_dir, unblink_data_dir, feature_func= feature_func_frp, n_frames_per_vid=10, type_= 'test')

train_loader= torch.utils.data.DataLoader(get_dataset(dataset_train), batch_size= 10, shuffle=True, drop_last= True)
val_loader=  torch.utils.data.DataLoader(get_dataset(dataset_test), batch_size= 10, shuffle=False, drop_last= True)

n_epochs= 100
show_epoch= 10
save_epoch= 10

train(model, criterion, opt, train_loader, val_loader, n_epochs, device, show_epoch, save_epoch)
# Out:
# no faces : /content/blink/63/10/00012.bmp
# features not extracted : 0
# features not extracted : 1
# no faces : /content/blink/53/10/00017.bmp
# features not extracted : 2
# no faces : /content/blink/46/10/00025.bmp
# features not extracted : 3
# no faces : /content/blink/55/10/00031.bmp
# features not extracted : 4
# no faces : /content/unblink/28/10/00018.bmp
# features not extracted : 5
# no faces : /content/blink/78/10/00012.bmp
# features not extracted : 6
# no faces : /content/blink/39/10/00020.bmp
# features not extracted : 7
# no faces : /content/blink/47/10/00009.bmp
# features not extracted : 8
# no faces : /content/unblink/78/10/13031.bmp
# features not extracted : 9
# no faces : /content/unblink/93/10/33402.bmp
# features not extracted : 10
# features not extracted : 11
# no faces : /content/blink/77/10/00039.bmp
# features not extracted : 12
# no faces : /content/blink/70/10/00028.bmp
# features not extracted : 13
# features not extracted : 14
# features not extracted : 15
# features not extracted : 16
# features not extracted : 17
# no faces : /content/blink/76/10/00126.bmp
# features not extracted : 18
# features not extracted : 19
# features not extracted : 20
# features not extracted : 21
# features not extracted : 22
# features not extracted : 23
# no faces : /content/unblink/29/10/00028.bmp
# features not extracted : 24
# features not extracted : 25
# no faces : /content/blink/120/10/58086.bmp
# features not extracted : 26
# no faces : /content/blink/41/10/00007.bmp
# features not extracted : 27
# features not extracted : 28
# features not extracted : 29
# no faces : /content/unblink/67/10/09413.bmp
# features not extracted : 30
# features not extracted : 31
# no faces : /content/unblink/64/10/09318.bmp
# features not extracted : 32
# no faces : /content/blink/27/10/00004.bmp
# features not extracted : 33
# features not extracted : 34
# no faces : /content/unblink/90/10/33369.bmp
# features not extracted : 35
# features not extracted : 36
# no faces : /content/blink/92/10/01178.bmp
# features not extracted : 37
# no faces : /content/blink/4/10/00046.bmp
# features not extracted : 38
# features not extracted : 39
# no faces : /content/blink/117/10/11290.bmp
# features not extracted : 40
# features not extracted : 41
# features not extracted : 42
# no faces : /content/unblink/1/10/00003.bmp
# features not extracted : 43
# no faces : /content/blink/48/10/00031.bmp
# features not extracted : 44
# no faces : /content/unblink/49/10/00002.bmp
# features not extracted : 45
# features not extracted : 46
# no faces : /content/blink/10/10/00007.bmp
# features not extracted : 47
# features not extracted : 48
# no faces : /content/blink/38/10/00006.bmp
# features not extracted : 49
# features not extracted : 50
# features not extracted : 51
# no faces : /content/blink/37/10/00002.bmp
# features not extracted : 52
# features not extracted : 53
# features not extracted : 54
# no faces : /content/blink/83/10/00037.bmp
# features not extracted : 55
# features not extracted : 56
# features not extracted : 57
# no faces : /content/blink/31/10/00006.bmp
# features not extracted : 58
# length features are not 10 !!!
# no faces : /content/unblink/12/10/00004.bmp
# features not extracted : 60
# no faces : /content/unblink/97/10/81847.bmp
# features not extracted : 61
# features not extracted : 62
# no faces : /content/blink/105/10/14075.bmp
# features not extracted : 63
# features not extracted : 64
# no faces : /content/blink/2/10/00002.bmp
# features not extracted : 65
# no faces : /content/unblink/5/10/00049.bmp
# features not extracted : 66
# features not extracted : 67
# features not extracted : 68
# no faces : /content/unblink/2/10/00016.bmp
# features not extracted : 69
# features not extracted : 70
# no faces : /content/unblink/79/10/13043.bmp
# features not extracted : 71
# features not extracted : 72
# features not extracted : 73
# features not extracted : 74
# no faces : /content/blink/5/10/00019.bmp
# features not extracted : 75
# features not extracted : 76
# features not extracted : 77
# features not extracted : 78
# no faces : /content/unblink/86/10/21292.bmp
# features not extracted : 79
# no faces : /content/blink/74/10/00055.bmp
# features not extracted : 80
# no faces : /content/blink/23/10/00016.bmp
# features not extracted : 81
# no faces : /content/unblink/4/10/00045.bmp
# features not extracted : 82
# no faces : /content/blink/118/10/11474.bmp
# features not extracted : 83
# features not extracted : 84
# features not extracted : 85
# no faces : /content/unblink/66/10/09360.bmp
# features not extracted : 86
# no faces : /content/blink/52/10/00008.bmp
# features not extracted : 87
# no faces : /content/blink/94/10/01208.bmp
# features not extracted : 88
# features not extracted : 89
# features not extracted : 90
# no faces : /content/unblink/69/10/09895.bmp
# features not extracted : 91
# features not extracted : 92
# no faces : /content/unblink/62/10/09113.bmp
# features not extracted : 93
# no faces : /content/blink/45/10/00007.bmp
# features not extracted : 94
# features not extracted : 95
# features not extracted : 96
# no faces : /content/blink/19/10/00001.bmp
# features not extracted : 97
# features not extracted : 98
# features not extracted : 99
# features not extracted : 100
# features not extracted : 101
# no faces : /content/unblink/14/10/00003.bmp
# features not extracted : 102
# no faces : /content/unblink/9/10/00042.bmp
# features not extracted : 103
# features not extracted : 104
# no faces : /content/unblink/65/10/09347.bmp
# features not extracted : 105
# no faces : /content/unblink/68/10/09422.bmp
# features not extracted : 106
# length features are not 10 !!!
# features not extracted : 108
# features not extracted : 109
# no faces : /content/blink/8/10/00011.bmp
# features not extracted : 110
# no faces : /content/blink/58/10/00013.bmp
# features not extracted : 111
# features not extracted : 112
# features not extracted : 113
# features not extracted : 114
# no faces : /content/blink/28/10/00017.bmp
# features not extracted : 115
# features not extracted : 116
# features not extracted : 117
# features not extracted : 118
# length features are not 10 !!!
# features not extracted : 120
# features not extracted : 121
# no faces : /content/unblink/85/10/13459.bmp
# features not extracted : 122
# features not extracted : 123
# no faces : /content/blink/111/10/04849.bmp
# features not extracted : 124
# features not extracted : 125
# no faces : /content/blink/59/10/00008.bmp
# features not extracted : 126
# features not extracted : 127
# features not extracted : 128
# no faces : /content/blink/125/10/175783.bmp
# features not extracted : 129
# no faces : /content/blink/101/10/12424.bmp
# features not extracted : 130
# no faces : /content/blink/12/10/00053.bmp
# features not extracted : 131
# no faces : /content/unblink/10/10/00050.bmp
# features not extracted : 132
# no faces : /content/blink/25/10/00016.bmp
# features not extracted : 133
# features not extracted : 134
# no faces : /content/blink/72/10/00029.bmp
# features not extracted : 135
# no faces : /content/unblink/6/10/00003.bmp
# features not extracted : 136
# features not extracted : 137
# features not extracted : 138
# features not extracted : 139
# no faces : /content/unblink/77/10/13018.bmp
# features not extracted : 140
# no faces : /content/blink/11/10/00016.bmp
# features not extracted : 141
# features not extracted : 142
# no faces : /content/blink/109/10/03850.bmp
# features not extracted : 143
# no faces : /content/blink/61/10/00005.bmp
# features not extracted : 144
# no faces : /content/unblink/16/10/00030.bmp
# features not extracted : 145
# features not extracted : 146
# no faces : /content/unblink/7/10/00016.bmp
# features not extracted : 147
# no faces : /content/unblink/48/10/00010.bmp
# features not extracted : 148
# features not extracted : 149
# features not extracted : 150
# no faces : /content/blink/82/10/00224.bmp
# features not extracted : 151
# no faces : /content/blink/3/10/00013.bmp
# features not extracted : 152
# no faces : /content/unblink/34/10/00030.bmp
# features not extracted : 153
# features not extracted : 154
# features not extracted : 155
# features not extracted : 156
# no faces : /content/unblink/15/10/00017.bmp
# features not extracted : 157
# no faces : /content/blink/24/10/00025.bmp
# features not extracted : 158
# no faces : /content/blink/71/10/00088.bmp
# features not extracted : 159
# no faces : /content/unblink/76/10/13004.bmp
# features not extracted : 160
# features not extracted : 161
# no faces : /content/unblink/17/10/00042.bmp
# features not extracted : 162
# no faces : /content/unblink/26/10/00042.bmp
# features not extracted : 163
# features not extracted : 164
# no faces : /content/unblink/8/10/00029.bmp
# features not extracted : 165
# features not extracted : 166
# features not extracted : 167
# features not extracted : 168
# features not extracted : 169
# features not extracted : 170
# no faces : /content/blink/51/10/00009.bmp
# features not extracted : 171
# no faces : /content/unblink/92/10/33392.bmp
# features not extracted : 172
# features not extracted : 173
# no faces : /content/blink/7/10/00012.bmp
# features not extracted : 174
# features not extracted : 175
# no faces : /content/unblink/30/10/00043.bmp
# features not extracted : 176
# features not extracted : 177
# no faces : /content/blink/69/10/00538.bmp
# features not extracted : 178
# features not extracted : 179
# no faces : /content/blink/123/10/139940.bmp
# features not extracted : 0
# features not extracted : 1
# no faces : /content/blink/36/10/00019.bmp
# features not extracted : 2
# features not extracted : 3
# features not extracted : 4
# features not extracted : 5
# features not extracted : 6
# no faces : /content/unblink/38/10/00014.bmp
# features not extracted : 7
# features not extracted : 8
# features not extracted : 9
# features not extracted : 10
# no faces : /content/unblink/22/10/3.bmp
# features not extracted : 11
# features not extracted : 12
# no faces : /content/unblink/33/10/00006.bmp
# features not extracted : 13
# no faces : /content/blink/110/10/04825.bmp
# features not extracted : 14
# no faces : /content/blink/54/10/00024.bmp
# features not extracted : 15
