# %%
from google.colab import drive

drive.mount('/content/gdrive') # experiments

# !rm -rf /content/dataset
# !mkdir -p /content/dataset
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Sync datasets from Drive

# %%
# !rm -rf /content/full_hust_dataset_combined
# !mkdir /content/full_hust_dataset_combined

import glob, shutil
for data_file in glob.glob(f'/content/gdrive/My Drive/full_hust_dataset_combined/*test*.zip'):

  file_name = data_file.split('/')[-1].replace('test', 'train')
  shutil.copyfile(data_file, f'/content/full_hust_dataset_combined/{file_name}')

# %%
glob.glob('/content/*/*train*.zip')
# Out:
# ['/content/full_hust_dataset_combined/combined_train_unblink.zip',
#  '/content/full_hust_dataset_combined/combined_train_blink.zip']

# %%
# %%capture
for zip_file in glob.glob('/content/*/*train*.zip'):
  # !unzip $zip_file
  # !rm -rf $zip_file

# %% [markdown]
# ## Update modules

# %%
import shutil, os

def send_modules():
  if not os.path.isdir('/content/modules'):
    print("No modules in Colab !!!")
    return 0 
  # !rm -rf '/content/gdrive/My Drive/EyeTracking/modules'
  shutil.copytree('/content/modules', '/content/gdrive/My Drive/EyeTracking/modules')
  print(f'modules send to : /content/gdrive/My Drive/EyeTracking/modules')
def recieve_modules():
  # !rm -rf '/content/modules'
  shutil.copytree('/content/gdrive/My Drive/EyeTracking/modules', '/content/modules')
  print('modules recieved to : /content/modules')

# %%
#recieve_modules()
#send_modules()
# Out:
# modules send to : /content/gdrive/My Drive/EyeTracking/modules

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from modules.get_features import get_features_for_sample
from modules.data_utils import get_dataset_filedirvslabel
from modules.feature_functions import feature_func_eyeimages, feature_func_frp
from modules.detectors import get_detectors
from modules.eyeimage_features import eyeimages2lbp


blink_data_dir = '/content/blink'
unblink_data_dir= '/content/unblink'

# %% [markdown]
# ## Create dataset

# %%
import numpy as np
def create_feature_dataset(blink_data_dir, unblink_data_dir, feature_func= feature_func_frp, n_frames_per_vid=10, type_= 'train', train_ratio=0.8):
  dataset =[]

  np.random.seed(10)
  dataset_filedirvslabel_all = sorted(list(get_dataset_filedirvslabel(blink_data_dir))+ list(get_dataset_filedirvslabel(unblink_data_dir)))
  np.random.shuffle(dataset_filedirvslabel_all)

  train_len= int(len(dataset_filedirvslabel_all)*train_ratio)

  if type_=='train':dataset_filedirvslabel= dataset_filedirvslabel_all[:train_len]
  else:dataset_filedirvslabel= dataset_filedirvslabel_all[train_len:]

  #for dataset_filedirvslabel_sample in dataset_filedirvslabel:
  #  sample_id = int(dataset_filedirvslabel_sample[0][0].split('/')[-3])

  for sample_id in range(len(dataset_filedirvslabel)):
    print(f'sample_id : {sample_id}/ {len(dataset_filedirvslabel)}')
    detector, landmark_detector = get_detectors()
    features, label = get_features_for_sample(dataset_filedirvslabel, sample_id, feature_func, detector, landmark_detector, check_errors=False)
    try:
      features.shape #to check features is not None

      if len(features[0])==n_frames_per_vid:
        dataset.append([features,label])
      else:print('length features are not 10 !!!')

    except:
      if features==None:print(f'features not extracted : sample_id : {sample_id}')
      else:print('error not handled')
  return dataset

# %% [markdown]
# ## Train

# %%
import torch
from torch import nn

dataset_train = create_feature_dataset(blink_data_dir, unblink_data_dir, feature_func= feature_func_eyeimages, n_frames_per_vid=10, type_= 'train')
dataset_test = create_feature_dataset(blink_data_dir, unblink_data_dir, feature_func= feature_func_eyeimages, n_frames_per_vid=10, type_= 'test')
# Out:
# sample_id : 0/ 180
# no faces detected : /content/blink/63/10/00012.bmp
# features not extracted : sample_id : 0
# sample_id : 1/ 180
# sample_id : 2/ 180
# no faces detected : /content/blink/53/10/00017.bmp
# features not extracted : sample_id : 2
# sample_id : 3/ 180
# no faces detected : /content/blink/46/10/00025.bmp
# features not extracted : sample_id : 3
# sample_id : 4/ 180
# no faces detected : /content/blink/55/10/00031.bmp
# features not extracted : sample_id : 4
# sample_id : 5/ 180
# no faces detected : /content/unblink/28/10/00018.bmp
# features not extracted : sample_id : 5
# sample_id : 6/ 180
# no faces detected : /content/blink/78/10/00012.bmp
# features not extracted : sample_id : 6
# sample_id : 7/ 180
# no faces detected : /content/blink/39/10/00020.bmp
# features not extracted : sample_id : 7
# sample_id : 8/ 180
# no faces detected : /content/blink/47/10/00009.bmp
# features not extracted : sample_id : 8
# sample_id : 9/ 180
# no faces detected : /content/unblink/78/10/13031.bmp
# features not extracted : sample_id : 9
# sample_id : 10/ 180
# no faces detected : /content/unblink/93/10/33402.bmp
# features not extracted : sample_id : 10
# sample_id : 11/ 180
# sample_id : 12/ 180
# no faces detected : /content/blink/77/10/00039.bmp
# features not extracted : sample_id : 12
# sample_id : 13/ 180
# no faces detected : /content/blink/70/10/00028.bmp
# features not extracted : sample_id : 13
# sample_id : 14/ 180
# sample_id : 15/ 180
# sample_id : 16/ 180
# sample_id : 17/ 180
# sample_id : 18/ 180
# no faces detected : /content/blink/76/10/00126.bmp
# features not extracted : sample_id : 18
# sample_id : 19/ 180
# sample_id : 20/ 180
# sample_id : 21/ 180
# sample_id : 22/ 180
# sample_id : 23/ 180
# sample_id : 24/ 180
# no faces detected : /content/unblink/29/10/00028.bmp
# features not extracted : sample_id : 24
# sample_id : 25/ 180
# sample_id : 26/ 180
# no faces detected : /content/blink/120/10/58086.bmp
# features not extracted : sample_id : 26
# sample_id : 27/ 180
# no faces detected : /content/blink/41/10/00007.bmp
# features not extracted : sample_id : 27
# sample_id : 28/ 180
# sample_id : 29/ 180
# sample_id : 30/ 180
# no faces detected : /content/unblink/67/10/09413.bmp
# features not extracted : sample_id : 30
# sample_id : 31/ 180
# sample_id : 32/ 180
# no faces detected : /content/unblink/64/10/09318.bmp
# features not extracted : sample_id : 32
# sample_id : 33/ 180
# no faces detected : /content/blink/27/10/00004.bmp
# features not extracted : sample_id : 33
# sample_id : 34/ 180
# sample_id : 35/ 180
# no faces detected : /content/unblink/90/10/33369.bmp
# features not extracted : sample_id : 35
# sample_id : 36/ 180
# sample_id : 37/ 180
# no faces detected : /content/blink/92/10/01178.bmp
# features not extracted : sample_id : 37
# sample_id : 38/ 180
# no faces detected : /content/blink/4/10/00046.bmp
# features not extracted : sample_id : 38
# sample_id : 39/ 180
# sample_id : 40/ 180
# no faces detected : /content/blink/117/10/11290.bmp
# features not extracted : sample_id : 40
# sample_id : 41/ 180
# sample_id : 42/ 180
# sample_id : 43/ 180
# no faces detected : /content/unblink/1/10/00003.bmp
# features not extracted : sample_id : 43
# sample_id : 44/ 180
# no faces detected : /content/blink/48/10/00031.bmp
# features not extracted : sample_id : 44
# sample_id : 45/ 180
# no faces detected : /content/unblink/49/10/00002.bmp
# features not extracted : sample_id : 45
# sample_id : 46/ 180
# sample_id : 47/ 180
# no faces detected : /content/blink/10/10/00007.bmp
# features not extracted : sample_id : 47
# sample_id : 48/ 180
# sample_id : 49/ 180
# no faces detected : /content/blink/38/10/00006.bmp
# features not extracted : sample_id : 49
# sample_id : 50/ 180
# sample_id : 51/ 180
# sample_id : 52/ 180
# no faces detected : /content/blink/37/10/00002.bmp
# features not extracted : sample_id : 52
# sample_id : 53/ 180
# sample_id : 54/ 180
# sample_id : 55/ 180
# no faces detected : /content/blink/83/10/00037.bmp
# features not extracted : sample_id : 55
# sample_id : 56/ 180
# sample_id : 57/ 180
# sample_id : 58/ 180
# no faces detected : /content/blink/31/10/00006.bmp
# features not extracted : sample_id : 58
# sample_id : 59/ 180
# length features are not 10 !!!
# sample_id : 60/ 180
# no faces detected : /content/unblink/12/10/00004.bmp
# features not extracted : sample_id : 60
# sample_id : 61/ 180
# no faces detected : /content/unblink/97/10/81847.bmp
# features not extracted : sample_id : 61
# sample_id : 62/ 180
# sample_id : 63/ 180
# no faces detected : /content/blink/105/10/14075.bmp
# features not extracted : sample_id : 63
# sample_id : 64/ 180
# sample_id : 65/ 180
# no faces detected : /content/blink/2/10/00002.bmp
# features not extracted : sample_id : 65
# sample_id : 66/ 180
# no faces detected : /content/unblink/5/10/00049.bmp
# features not extracted : sample_id : 66
# sample_id : 67/ 180
# sample_id : 68/ 180
# sample_id : 69/ 180
# no faces detected : /content/unblink/2/10/00016.bmp
# features not extracted : sample_id : 69
# sample_id : 70/ 180
# sample_id : 71/ 180
# no faces detected : /content/unblink/79/10/13043.bmp
# features not extracted : sample_id : 71
# sample_id : 72/ 180
# sample_id : 73/ 180
# sample_id : 74/ 180
# sample_id : 75/ 180
# no faces detected : /content/blink/5/10/00019.bmp
# features not extracted : sample_id : 75
# sample_id : 76/ 180
# sample_id : 77/ 180
# sample_id : 78/ 180
# sample_id : 79/ 180
# no faces detected : /content/unblink/86/10/21292.bmp
# features not extracted : sample_id : 79
# sample_id : 80/ 180
# no faces detected : /content/blink/74/10/00055.bmp
# features not extracted : sample_id : 80
# sample_id : 81/ 180
# no faces detected : /content/blink/23/10/00016.bmp
# features not extracted : sample_id : 81
# sample_id : 82/ 180
# no faces detected : /content/unblink/4/10/00045.bmp
# features not extracted : sample_id : 82
# sample_id : 83/ 180
# no faces detected : /content/blink/118/10/11474.bmp
# features not extracted : sample_id : 83
# sample_id : 84/ 180
# sample_id : 85/ 180
# sample_id : 86/ 180
# no faces detected : /content/unblink/66/10/09360.bmp
# features not extracted : sample_id : 86
# sample_id : 87/ 180
# no faces detected : /content/blink/52/10/00008.bmp
# features not extracted : sample_id : 87
# sample_id : 88/ 180
# no faces detected : /content/blink/94/10/01208.bmp
# features not extracted : sample_id : 88
# sample_id : 89/ 180
# sample_id : 90/ 180
# sample_id : 91/ 180
# no faces detected : /content/unblink/69/10/09895.bmp
# features not extracted : sample_id : 91
# sample_id : 92/ 180
# sample_id : 93/ 180
# no faces detected : /content/unblink/62/10/09113.bmp
# features not extracted : sample_id : 93
# sample_id : 94/ 180
# no faces detected : /content/blink/45/10/00007.bmp
# features not extracted : sample_id : 94
# sample_id : 95/ 180
# sample_id : 96/ 180
# sample_id : 97/ 180
# no faces detected : /content/blink/19/10/00001.bmp
# features not extracted : sample_id : 97
# sample_id : 98/ 180
# sample_id : 99/ 180
# sample_id : 100/ 180
# sample_id : 101/ 180
# sample_id : 102/ 180
# no faces detected : /content/unblink/14/10/00003.bmp
# features not extracted : sample_id : 102
# sample_id : 103/ 180
# no faces detected : /content/unblink/9/10/00042.bmp
# features not extracted : sample_id : 103
# sample_id : 104/ 180
# sample_id : 105/ 180
# no faces detected : /content/unblink/65/10/09347.bmp
# features not extracted : sample_id : 105
# sample_id : 106/ 180
# no faces detected : /content/unblink/68/10/09422.bmp
# features not extracted : sample_id : 106
# sample_id : 107/ 180
# length features are not 10 !!!
# sample_id : 108/ 180
# sample_id : 109/ 180
# sample_id : 110/ 180
# no faces detected : /content/blink/8/10/00011.bmp
# features not extracted : sample_id : 110
# sample_id : 111/ 180
# no faces detected : /content/blink/58/10/00013.bmp
# features not extracted : sample_id : 111
# sample_id : 112/ 180
# sample_id : 113/ 180
# sample_id : 114/ 180
# sample_id : 115/ 180
# no faces detected : /content/blink/28/10/00017.bmp
# features not extracted : sample_id : 115
# sample_id : 116/ 180
# sample_id : 117/ 180
# sample_id : 118/ 180
# sample_id : 119/ 180
# length features are not 10 !!!
# sample_id : 120/ 180
# sample_id : 121/ 180
# sample_id : 122/ 180
# no faces detected : /content/unblink/85/10/13459.bmp
# features not extracted : sample_id : 122
# sample_id : 123/ 180
# sample_id : 124/ 180
# no faces detected : /content/blink/111/10/04849.bmp
# features not extracted : sample_id : 124
# sample_id : 125/ 180
# sample_id : 126/ 180
# no faces detected : /content/blink/59/10/00008.bmp
# features not extracted : sample_id : 126
# sample_id : 127/ 180
# sample_id : 128/ 180
# sample_id : 129/ 180
# no faces detected : /content/blink/125/10/175783.bmp
# features not extracted : sample_id : 129
# sample_id : 130/ 180
# no faces detected : /content/blink/101/10/12424.bmp
# features not extracted : sample_id : 130
# sample_id : 131/ 180
# no faces detected : /content/blink/12/10/00053.bmp
# features not extracted : sample_id : 131
# sample_id : 132/ 180
# no faces detected : /content/unblink/10/10/00050.bmp
# features not extracted : sample_id : 132
# sample_id : 133/ 180
# no faces detected : /content/blink/25/10/00016.bmp
# features not extracted : sample_id : 133
# sample_id : 134/ 180
# sample_id : 135/ 180
# no faces detected : /content/blink/72/10/00029.bmp
# features not extracted : sample_id : 135
# sample_id : 136/ 180
# no faces detected : /content/unblink/6/10/00003.bmp
# features not extracted : sample_id : 136
# sample_id : 137/ 180
# sample_id : 138/ 180
# sample_id : 139/ 180
# sample_id : 140/ 180
# no faces detected : /content/unblink/77/10/13018.bmp
# features not extracted : sample_id : 140
# sample_id : 141/ 180
# no faces detected : /content/blink/11/10/00016.bmp
# features not extracted : sample_id : 141
# sample_id : 142/ 180
# sample_id : 143/ 180
# no faces detected : /content/blink/109/10/03850.bmp
# features not extracted : sample_id : 143
# sample_id : 144/ 180
# no faces detected : /content/blink/61/10/00005.bmp
# features not extracted : sample_id : 144
# sample_id : 145/ 180
# no faces detected : /content/unblink/16/10/00030.bmp
# features not extracted : sample_id : 145
# sample_id : 146/ 180
# sample_id : 147/ 180
# no faces detected : /content/unblink/7/10/00016.bmp
# features not extracted : sample_id : 147
# sample_id : 148/ 180
# no faces detected : /content/unblink/48/10/00010.bmp
# features not extracted : sample_id : 148
# sample_id : 149/ 180
# sample_id : 150/ 180
# sample_id : 151/ 180
# no faces detected : /content/blink/82/10/00224.bmp
# features not extracted : sample_id : 151
# sample_id : 152/ 180
# no faces detected : /content/blink/3/10/00013.bmp
# features not extracted : sample_id : 152
# sample_id : 153/ 180
# no faces detected : /content/unblink/34/10/00030.bmp
# features not extracted : sample_id : 153
# sample_id : 154/ 180
# sample_id : 155/ 180
# sample_id : 156/ 180
# sample_id : 157/ 180
# no faces detected : /content/unblink/15/10/00017.bmp
# features not extracted : sample_id : 157
# sample_id : 158/ 180
# no faces detected : /content/blink/24/10/00025.bmp
# features not extracted : sample_id : 158
# sample_id : 159/ 180
# no faces detected : /content/blink/71/10/00088.bmp
# features not extracted : sample_id : 159
# sample_id : 160/ 180
# no faces detected : /content/unblink/76/10/13004.bmp
# features not extracted : sample_id : 160
# sample_id : 161/ 180
# sample_id : 162/ 180
# no faces detected : /content/unblink/17/10/00042.bmp
# features not extracted : sample_id : 162
# sample_id : 163/ 180
# no faces detected : /content/unblink/26/10/00042.bmp
# features not extracted : sample_id : 163
# sample_id : 164/ 180
# sample_id : 165/ 180
# no faces detected : /content/unblink/8/10/00029.bmp
# features not extracted : sample_id : 165
# sample_id : 166/ 180
# sample_id : 167/ 180
# sample_id : 168/ 180
# sample_id : 169/ 180
# sample_id : 170/ 180
# sample_id : 171/ 180
# no faces detected : /content/blink/51/10/00009.bmp
# features not extracted : sample_id : 171
# sample_id : 172/ 180
# no faces detected : /content/unblink/92/10/33392.bmp
# features not extracted : sample_id : 172
# sample_id : 173/ 180
# sample_id : 174/ 180
# no faces detected : /content/blink/7/10/00012.bmp
# features not extracted : sample_id : 174
# sample_id : 175/ 180
# sample_id : 176/ 180
# no faces detected : /content/unblink/30/10/00043.bmp
# features not extracted : sample_id : 176
# sample_id : 177/ 180
# sample_id : 178/ 180
# no faces detected : /content/blink/69/10/00538.bmp
# features not extracted : sample_id : 178
# sample_id : 179/ 180
# sample_id : 0/ 45
# no faces detected : /content/blink/123/10/139940.bmp
# features not extracted : sample_id : 0
# sample_id : 1/ 45
# sample_id : 2/ 45
# no faces detected : /content/blink/36/10/00019.bmp
# features not extracted : sample_id : 2
# sample_id : 3/ 45
# sample_id : 4/ 45
# sample_id : 5/ 45
# sample_id : 6/ 45
# sample_id : 7/ 45
# no faces detected : /content/unblink/38/10/00014.bmp
# features not extracted : sample_id : 7
# sample_id : 8/ 45
# sample_id : 9/ 45
# sample_id : 10/ 45
# sample_id : 11/ 45
# no faces detected : /content/unblink/22/10/3.bmp
# features not extracted : sample_id : 11
# sample_id : 12/ 45
# sample_id : 13/ 45
# no faces detected : /content/unblink/33/10/00006.bmp
# features not extracted : sample_id : 13
# sample_id : 14/ 45
# no faces detected : /content/blink/110/10/04825.bmp
# features not extracted : sample_id : 14
# sample_id : 15/ 45
# no faces detected : /content/blink/54/10/00024.bmp
# features not extracted : sample_id : 15
# sample_id : 16/ 45
# no faces detected : /content/unblink/80/10/13057.bmp
# features not extracted : sample_id : 16
# sample_id : 17/ 45
# sample_id : 18/ 45
# no faces detected : /content/unblink/55/10/06660.bmp
# features not extracted : sample_id : 18
# sample_id : 19/ 45
# sample_id : 20/ 45
# no faces detected : /content/blink/14/10/00005.bmp
# features not extracted : sample_id : 20
# sample_id : 21/ 45
# sample_id : 22/ 45
# sample_id : 23/ 45
# no faces detected : /content/blink/81/10/00058.bmp
# features not extracted : sample_id : 23
# sample_id : 24/ 45
# no faces detected : /content/blink/64/10/00008.bmp
# features not extracted : sample_id : 24
# sample_id : 25/ 45
# sample_id : 26/ 45
# sample_id : 27/ 45
# no faces detected : /content/blink/75/10/00040.bmp
# features not extracted : sample_id : 27
# sample_id : 28/ 45
# no faces detected : /content/blink/113/10/09778.bmp
# features not extracted : sample_id : 28
# sample_id : 29/ 45
# sample_id : 30/ 45
# sample_id : 31/ 45
# sample_id : 32/ 45
# sample_id : 33/ 45
# no faces detected : /content/blink/50/10/00008.bmp
# features not extracted : sample_id : 33
# sample_id : 34/ 45
# sample_id : 35/ 45
# sample_id : 36/ 45
# no faces detected : /content/unblink/37/10/00002.bmp
# features not extracted : sample_id : 36
# sample_id : 37/ 45
# no faces detected : /content/unblink/91/10/33378.bmp
# features not extracted : sample_id : 37
# sample_id : 38/ 45
# sample_id : 39/ 45
# sample_id : 40/ 45
# sample_id : 41/ 45
# sample_id : 42/ 45
# no faces detected : /content/blink/112/10/09629.bmp
# features not extracted : sample_id : 42
# sample_id : 43/ 45
# sample_id : 44/ 45

# %%
from modules.nn_models import cnn_lstm
from modules.data import get_dataset_eye
from modules.train import train

# %%
feature_len= 250
torch.manual_seed(10)

device= 'cuda' if torch.cuda.is_available() else 'cpu'
model = cnn_lstm(lstm_input_feature_size= feature_len, bidirectional=True, dropout= 0.7).to(device)
criterion= nn.BCELoss().to(device)
opt= torch.optim.Adam(model.parameters(), lr= 0.001)

# %%
torch.manual_seed(10)

train_loader= torch.utils.data.DataLoader(get_dataset_eye(dataset_train), batch_size= 10, shuffle=True, drop_last= True)
val_loader=  torch.utils.data.DataLoader(get_dataset_eye(dataset_test), batch_size= 10, shuffle=False, drop_last= True)

n_epochs= 1250
show_epoch= 50
save_epoch= 50

train(model, criterion, opt, train_loader, val_loader, n_epochs, device, show_epoch, save_epoch)
# Out:
# skipping saving...
# skipping saving...
# skipping saving...
# skipping saving...
# skipping saving...
# skipping saving...
# skipping saving...
# skipping saving...
# skipping saving...
# skipping saving...
# skipping saving...
# skipping saving...
# skipping saving...
# skipping saving...
# skipping saving...
# skipping saving...
# skipping saving...
# skipping saving...
# skipping saving...
# skipping saving...
# skipping saving...
# skipping saving...
# skipping saving...
# skipping saving...
# skipping saving...
